# %%
import tensorflow as tf
import tensorflow_data_validation as tfdv
import tensorflow_transform as tft
import apache_beam as beam
import pandas as pd

print('Tf version: ', tf.__version__)
print('TFDV version: ', tfdv.__version__)
print('TFT version: ', tft.__version__)
print('Apache beam version: ', beam.__version__)
print('Pandas version: ', pd.__version__)
# Out:
# Tf version:  2.17.0
# TFDV version:  1.14.0
# TFT version:  1.14.0
# Apache beam version:  2.65.0
# Pandas version:  1.5.3

# %%
tfdv
# Out:
# <module 'tensorflow_data_validation' from 'C:\\Users\\shrim\\Documents\\src\\AI-ML\\feature-engineering\\diabetes\\tfx_env\\lib\\site-packages\\tensorflow_data_validation\\__init__.py'>
