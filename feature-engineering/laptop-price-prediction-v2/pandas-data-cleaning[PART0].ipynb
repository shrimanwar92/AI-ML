# %%
# # Fill missing numeric columns
# raw_df[num_cols] = raw_df[num_cols].fillna(raw_df[num_cols].median())

# # Coerce string to numeric
# raw_df['Price'] = pd.to_numeric(raw_df['Price'], errors='coerce').fillna(0)

# # Clip out-of-range
# raw_df['Weight'] = raw_df['Weight'].clip(0, 10)

# # Fill missing categories
# raw_df['Company'] = raw_df['Company'].fillna('unknown')

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/laptop_data_2.csv")
df.head()
# Out:
#   Company  TypeName  Inches ScreenResolution            Cpu   Ram     Memory  \
# 0    Dell  Notebook    13.0         1366x768    AMD Ryzen 5  16GB  128GB SSD
# 1  Lenovo   Netbook    11.1        3840x2160  Intel Celeron   8GB    2TB SSD
# 2    Acer  Notebook    17.1        1920x1080  Intel Core i7  16GB  512GB SSD
# 3  Lenovo  Notebook    14.4        3840x2160    AMD Ryzen 5  16GB  512GB SSD
# 4    Asus   Netbook    12.5        3200x1800    AMD Ryzen 5  16GB    1TB HDD
#
#                Gpu       OpSys Weight    Price
# 0  NVIDIA GTX 1650  Windows 10  2.5kg   2618.2
# 1        Intel UHD  Windows 11  2.0kg  1997.85
# 2        Intel UHD  Windows 10  2.0kg  1298.97
# 3        Intel UHD  Windows 11  2.0kg  2570.04
# 4        Intel UHD  Windows 11  2.5kg   1146.2

# %%
df.isnull().sum()
# Out:
# Company                 0
# TypeName                0
# Inches                  0
# ScreenResolution        0
# Cpu                     0
# Ram                 49943
# Memory                  0
# Gpu                 49916
# OpSys                   0
# Weight                  0
# Price                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 11 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Company           object
#  1   TypeName          object
#  2   Inches            float64
#  3   ScreenResolution  object
#  4   Cpu               object
#  5   Ram               object
#  6   Memory            object
#  7   Gpu               object
#  8   OpSys             object
#  9   Weight            object
#  10  Price             object
# dtypes: float64(1), object(10)
# memory usage: 839.2+ MB

# %%
print(df['Ram'].value_counts(dropna=False))
print("====================================")
print(df['Ram'].mean())
# Out:
# 16GB      2477603
# 4GB       2476560
# 8GB       2473675
# 32GB      2472162
# 1234TB      50057
# NaN         49943
# Name: Ram, dtype: int64
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 print(df['Ram'].value_counts(dropna=False))
#       2 print("====================================")
# ----> 3 print(df['Ram'].mean())
#
# File ~\Documents\src\AI-ML\feature-engineering\diabetes\tfx_env\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# ...
